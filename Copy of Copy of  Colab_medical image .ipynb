# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
labels = ['NORMAL', 'PNEUMONIA']
img_size = 224
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] 
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data('/content/drive/MyDrive/xray images/train')
val = get_data('/content/drive/MyDrive/xray images/test')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   from ipykernel import kernelapp as app

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("NORMAL")
    else:
        l.append("PNEUMONIA")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0])
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'PNEUMONIA')

# %%
#Data Preprocessing and Data Augmentation
x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
  x_train.append(feature)
  y_train.append(label)

for feature, label in val:
  x_val.append(feature)
  y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
from skimage import data, io


datagen = ImageDataGenerator( 

        
        rotation_range = 90,  # randomly rotate images in the range (degrees, 0 to 180)
        shear_range=0.35, # Float. Shear Intensity (Shear angle in counter-clockwise direction in degrees)
        brightness_range=[0.1,0.5], #Tuple or list of two floats. Range for picking a brightness shift value from.
        zoom_range = 0.5, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images
        
 
datagen.fit(x_train)

# %%
fig, axes = plt.subplots(ncols=7, nrows=2, figsize=(16, 4))

indices = np.random.choice(len(x_train), 14)
counter = 0

for i in range(2):
    for j in range(7):
        axes[i,j].set_title(y_train[indices[counter]])
        axes[i,j].imshow(x_train[indices[counter]], cmap='gray')
        axes[i,j].get_xaxis().set_visible(False)
        axes[i,j].get_yaxis().set_visible(False)
        counter += 1
plt.show()

# %%
model = Sequential()
model.add(Conv2D(32,3,padding="same", activation="relu", input_shape=(224,224,3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(2, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               6422656
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 6,451,554
# Trainable params: 6,451,554
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(lr=0.000001)
model.compile(optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs = 50 , validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 164/164 [==============================] - 192s 1s/step - loss: 0.5965 - accuracy: 0.7417 - val_loss: 0.6965 - val_accuracy: 0.6250
# Epoch 2/50
# 164/164 [==============================] - 193s 1s/step - loss: 0.5447 - accuracy: 0.7545 - val_loss: 0.6511 - val_accuracy: 0.6250
# Epoch 3/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.5293 - accuracy: 0.7431 - val_loss: 0.6353 - val_accuracy: 0.6250
# Epoch 4/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.4888 - accuracy: 0.7463 - val_loss: 0.6203 - val_accuracy: 0.6250
# Epoch 5/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.4496 - accuracy: 0.7602 - val_loss: 0.5771 - val_accuracy: 0.6298
# Epoch 6/50
# 164/164 [==============================] - 187s 1s/step - loss: 0.4188 - accuracy: 0.8014 - val_loss: 0.5407 - val_accuracy: 0.6506
# Epoch 7/50
# 164/164 [==============================] - 187s 1s/step - loss: 0.3774 - accuracy: 0.8442 - val_loss: 0.5384 - val_accuracy: 0.6587
# Epoch 8/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.3479 - accuracy: 0.8684 - val_loss: 0.4977 - val_accuracy: 0.7099
# Epoch 9/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.3167 - accuracy: 0.8833 - val_loss: 0.4746 - val_accuracy: 0.7308
# Epoch 10/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.2974 - accuracy: 0.8982 - val_loss: 0.4835 - val_accuracy: 0.7244
# Epoch 11/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.2773 - accuracy: 0.9043 - val_loss: 0.4653 - val_accuracy: 0.7452
# Epoch 12/50
# 164/164 [==============================] - 191s 1s/step - loss: 0.2615 - accuracy: 0.9114 - val_loss: 0.4237 - val_accuracy: 0.7756
# Epoch 13/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.2491 - accuracy: 0.9200 - val_loss: 0.4481 - val_accuracy: 0.7580
# Epoch 14/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.2457 - accuracy: 0.9145 - val_loss: 0.4264 - val_accuracy: 0.7756
# Epoch 15/50
# 164/164 [==============================] - 191s 1s/step - loss: 0.2321 - accuracy: 0.9241 - val_loss: 0.4166 - val_accuracy: 0.7788
# Epoch 16/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.2257 - accuracy: 0.9222 - val_loss: 0.4269 - val_accuracy: 0.7756
# Epoch 17/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.2101 - accuracy: 0.9296 - val_loss: 0.4203 - val_accuracy: 0.7788
# Epoch 18/50
# 164/164 [==============================] - 191s 1s/step - loss: 0.1992 - accuracy: 0.9381 - val_loss: 0.3978 - val_accuracy: 0.8013
# Epoch 19/50
# 164/164 [==============================] - 191s 1s/step - loss: 0.1975 - accuracy: 0.9337 - val_loss: 0.4301 - val_accuracy: 0.7740
# Epoch 20/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.1958 - accuracy: 0.9352 - val_loss: 0.3967 - val_accuracy: 0.8061
# Epoch 21/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1909 - accuracy: 0.9368 - val_loss: 0.3958 - val_accuracy: 0.8109
# Epoch 22/50
# 164/164 [==============================] - 187s 1s/step - loss: 0.1697 - accuracy: 0.9481 - val_loss: 0.4050 - val_accuracy: 0.8013
# Epoch 23/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1767 - accuracy: 0.9402 - val_loss: 0.4282 - val_accuracy: 0.7853
# Epoch 24/50
# 164/164 [==============================] - 187s 1s/step - loss: 0.1733 - accuracy: 0.9444 - val_loss: 0.4099 - val_accuracy: 0.8061
# Epoch 25/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1606 - accuracy: 0.9478 - val_loss: 0.4182 - val_accuracy: 0.7981
# Epoch 26/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1611 - accuracy: 0.9453 - val_loss: 0.4136 - val_accuracy: 0.8045
# Epoch 27/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.1592 - accuracy: 0.9460 - val_loss: 0.4228 - val_accuracy: 0.7997
# Epoch 28/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1572 - accuracy: 0.9441 - val_loss: 0.4273 - val_accuracy: 0.7997
# Epoch 29/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.1497 - accuracy: 0.9474 - val_loss: 0.4037 - val_accuracy: 0.8093
# Epoch 30/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.1559 - accuracy: 0.9480 - val_loss: 0.4301 - val_accuracy: 0.8013
# Epoch 31/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1484 - accuracy: 0.9479 - val_loss: 0.4333 - val_accuracy: 0.7997
# Epoch 32/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1338 - accuracy: 0.9572 - val_loss: 0.4099 - val_accuracy: 0.8077
# Epoch 33/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1424 - accuracy: 0.9484 - val_loss: 0.4642 - val_accuracy: 0.7869
# Epoch 34/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1304 - accuracy: 0.9587 - val_loss: 0.4174 - val_accuracy: 0.8061
# Epoch 35/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.1326 - accuracy: 0.9585 - val_loss: 0.4286 - val_accuracy: 0.8045
# Epoch 36/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1329 - accuracy: 0.9545 - val_loss: 0.4381 - val_accuracy: 0.7981
# Epoch 37/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1325 - accuracy: 0.9579 - val_loss: 0.4596 - val_accuracy: 0.7933
# Epoch 38/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1232 - accuracy: 0.9575 - val_loss: 0.4031 - val_accuracy: 0.8173
# Epoch 39/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1194 - accuracy: 0.9630 - val_loss: 0.4366 - val_accuracy: 0.8029
# Epoch 40/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.1157 - accuracy: 0.9614 - val_loss: 0.4289 - val_accuracy: 0.8109
# Epoch 41/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1169 - accuracy: 0.9612 - val_loss: 0.5149 - val_accuracy: 0.7772
# Epoch 42/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1210 - accuracy: 0.9599 - val_loss: 0.4523 - val_accuracy: 0.7949
# Epoch 43/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1153 - accuracy: 0.9629 - val_loss: 0.4884 - val_accuracy: 0.7821
# Epoch 44/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1071 - accuracy: 0.9670 - val_loss: 0.4830 - val_accuracy: 0.7901
# Epoch 45/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1096 - accuracy: 0.9596 - val_loss: 0.4726 - val_accuracy: 0.7949
# Epoch 46/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1087 - accuracy: 0.9669 - val_loss: 0.4707 - val_accuracy: 0.7965
# Epoch 47/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1076 - accuracy: 0.9652 - val_loss: 0.4869 - val_accuracy: 0.7901
# Epoch 48/50
# 164/164 [==============================] - 189s 1s/step - loss: 0.1038 - accuracy: 0.9667 - val_loss: 0.4881 - val_accuracy: 0.7901
# Epoch 49/50
# 164/164 [==============================] - 188s 1s/step - loss: 0.1104 - accuracy: 0.9632 - val_loss: 0.4949 - val_accuracy: 0.7869
# Epoch 50/50
# 164/164 [==============================] - 190s 1s/step - loss: 0.1090 - accuracy: 0.9656 - val_loss: 0.4860 - val_accuracy: 0.7965

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(50)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
predictions = model.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = ['NORMAL (Class 0)','PNEUMONIA (Class 1)']))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                      precision    recall  f1-score   support
#
#    NORMAL (Class 0)       0.97      0.47      0.64       234
# PNEUMONIA (Class 1)       0.76      0.99      0.86       390
#
#            accuracy                           0.80       624
#           macro avg       0.86      0.73      0.75       624
#        weighted avg       0.84      0.80      0.78       624
